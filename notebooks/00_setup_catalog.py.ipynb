# %%
# Databricks notebook source
# 1. Create target schemas in Unity Catalog
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.bronze;")
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.silver;")
spark.sql("CREATE SCHEMA IF NOT EXISTS workspace.gold;")

# 2. Create the Unity Catalog Volume object explicitly
# (Creates volume 'healthflow_raw' under catalog 'workspace' and schema 'default')
spark.sql("CREATE VOLUME IF NOT EXISTS workspace.default.healthflow_raw;")

# 3. Create subdirectories inside the volume for raw landing & checkpoints
base_volume = "/Volumes/workspace/default/healthflow_raw"

dbutils.fs.mkdirs(f"{base_volume}/raw_data")
dbutils.fs.mkdirs(f"{base_volume}/checkpoints")

print("✅ HealthFlow Schemas, Volume, and landing folders initialized successfully!")
